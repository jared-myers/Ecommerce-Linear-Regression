# %% [markdown]
# # Linear Regression For E-Commerce

# %% [markdown]
# This project uses hypotethetical data for an ecommerce company that specializes in clothing and style advice sessions. After the advisory sessions, customers would go home and use either the website or mobile app to makes purchases.
#
# The goal of this project is to determine where focus should be prioritized, the website or the mobile app.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# About the Data
#
# Dataset contains customer Email, Address, and Avatar. The data that is relevant for the linear regression is below.
#
# Average session of style advice sessions.
# Time spent on app in minutes
# Time spent on website in minutes
# Length of membership time in years

# %%
customers = pd.read_csv('customer-usage.csv')
customers.head()
# Out:
#                        Email                         Address     Avatar  \
# 0  mstephenson@fernandez.com                835 Frank Tunnel        NaN
# 1                Wrightmouth                  MI 82180-9605"     Violet
# 2          hduke@hotmail.com              4547 Archer Common        NaN
# 3                Diazchester                  CA 06566-8576"  DarkGreen
# 4           pallen@yahoo.com  24645 Valerie Unions Suite 582        NaN
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0                  NaN          NaN              NaN                   NaN
# 1            34.497268    12.655651        39.577668              4.082621
# 2                  NaN          NaN              NaN                   NaN
# 3            31.926272    11.109461        37.268959              2.664034
# 4                  NaN          NaN              NaN                   NaN
#
#    Yearly Amount Spent
# 0                  NaN
# 1           587.951054
# 2                  NaN
# 3           392.204933
# 4                  NaN

# %%
# Remove customers data that is NaN
customers.dropna(inplace=True)
customers.head()
# Out:
#              Email          Address            Avatar  Avg. Session Length  \
# 1      Wrightmouth   MI 82180-9605"            Violet            34.497268
# 3      Diazchester   CA 06566-8576"         DarkGreen            31.926272
# 5      Cobbborough   DC 99414-7564"            Bisque            33.000915
# 7       Port Jason   OH 22070-1220"       SaddleBrown            34.305557
# 9  Port Jacobville   PR 37242-1057"  MediumAquaMarine            33.330673
#
#    Time on App  Time on Website  Length of Membership  Yearly Amount Spent
# 1    12.655651        39.577668              4.082621           587.951054
# 3    11.109461        37.268959              2.664034           392.204933
# 5    11.330278        37.110597              4.104543           487.547505
# 7    13.717514        36.721283              3.120179           581.852344
# 9    12.795189        37.536653              4.446308           599.406092

# %%
customers.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           454.000000   454.000000       454.000000
# mean             33.052615    12.041631        37.052822
# std               0.997603     0.979870         0.997863
# min              29.532429     8.508152        34.476878
# 25%              32.344967    11.378380        36.353186
# 50%              33.082008    11.966439        37.063155
# 75%              33.704236    12.723768        37.691560
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            454.000000           454.000000
# mean               3.546803           499.919858
# std                0.992032            78.325793
# min                0.269901           266.086341
# 25%                2.953864           445.917049
# 50%                3.534332           498.887875
# 75%                4.128087           549.100737
# max                6.401229           765.518462

# %% [markdown]
# ### Exploration

# %% [markdown]
# Visualizations will be used to get an idea of the relationship between yearly amount spent by the customer and the time spent on the website.

# %%
sns.jointplot(customers['Time on Website'],customers['Yearly Amount Spent'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Visualization of the relationship between yearly amount spent by the customer and the time spent on the mobile app.

# %%
sns.jointplot(customers['Time on App'],customers['Yearly Amount Spent'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# It appears that the correlation between time spent on and the mobile app and the yearly spend is less than the website and yearly spend. Now to check the relationship between time on the app and the website.

# %%
sns.pairplot(customers)

# %%
customers.corr()
# Out:
#                       Avg. Session Length  Time on App  Time on Website  \
# Avg. Session Length              1.000000    -0.023311        -0.028782
# Time on App                     -0.023311     1.000000         0.050493
# Time on Website                 -0.028782     0.050493         1.000000
# Length of Membership             0.031682     0.028582        -0.012059
# Yearly Amount Spent              0.342522     0.500014         0.013748
#
#                       Length of Membership  Yearly Amount Spent
# Avg. Session Length               0.031682             0.342522
# Time on App                       0.028582             0.500014
# Time on Website                  -0.012059             0.013748
# Length of Membership              1.000000             0.804974
# Yearly Amount Spent               0.804974             1.000000

# %% [markdown]
# Yearly spend is most highly correlated with the length of membership. Loyal customers spend more money so this is not unusual.

# %%
# Linear plot of membership length and yearly spend
sns.lmplot('Length of Membership','Yearly Amount Spent',data=customers)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Preparing Data for Modeling

# %%
customers.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
#Select only numerical features for training
X = customers[['Avg. Session Length', 'Time on App','Time on Website', 'Length of Membership']]
y = customers['Yearly Amount Spent']

# %%
# split the data into a training and testing set using 70/30 ratio
from sklearn.model_selection import train_test_split
X_test,X_train,y_test,y_train = train_test_split(X,y,test_size=0.3,random_state=101)

# %% [markdown]
# ### Model Training

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Testing Predictions

# %%
predictions = lm.predict(X_test)
# scatterplot of the real vs predicted values
plt.scatter(y_test,predictions)

# %% [markdown]
# The model performs well since the predictions seem to be linearly close to the real values.

# %% [markdown]
# ### Evaluating the Results

# %%
# Residual sum
from sklearn import metrics
print('MAE:',metrics.mean_absolute_error(y_test,predictions))
print('MSE:',metrics.mean_squared_error(y_test,predictions))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test,predictions)))
# Out:
# MAE: 8.134074258011399
# MSE: 103.09864151706178
# RMSE: 10.153750120869717

# %% [markdown]
# Coefficients for each variable

# %%
cust_coeff = pd.DataFrame(lm.coef_,X.columns)
cust_coeff.columns = ['Coefficient']
cust_coeff
# Out:
#                       Coefficient
# Avg. Session Length     25.744346
# Time on App             37.142011
# Time on Website          0.601293
# Length of Membership    61.868425

# %%
# Coefficients meaning

# 1 unit increase in the Avg. Session Length leads to an approximate $25 increase in yearly spend.
# 1 unit increase in the Time on App leads to an approximate $39 increase in yearly spend.
# 1 unit increase in the Time on Website leads to an approximate $0.77 increase in yearly spend.
# 1 unit increase in the Length of Membership leads to an approximate $62 increase in yearly spend.

# %% [markdown]
# ### Website vs App

# %% [markdown]
# Should the company focus more on the mobile app or the website?
#
# Between the two, the mobile app seems to be doing better than the website. Time spent on the mobile app produces more yearly spend than time spent on the website by a large margin.
#
# The company could prioritize the website in hopes of increasing the yearly spend from it to close the gap vs the mobile app or alternatively push usage of the mobile app since it already produces higher yearly spend.
#
# Since membership length has the greatest effect on yearly spend it would probably make sense to look into customer loyalty programs to increase customer retention even further.
